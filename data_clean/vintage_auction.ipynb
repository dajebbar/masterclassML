# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('https://bit.ly/vintage-auctions')

# %%
df.head()
# Out:
#                                       tx id      time auction       color  \
# 0  8dbf3cfa48b25f32e300f279bb4163c67d5c60cd   3:36 PM  $17.18        Puce
# 1  8ccebfdb1a41830bdcc0e926531f3215986b3a90   9:03 AM  $15.19  Aquamarine
# 2  ae85a421a91cec8baf16ff1e45fb3e239130b584   7:42 PM   $7.58      Violet
# 3  85e44f09a04a79182befcfd55e288a855f633e81  10:28 PM   $9.10   Goldenrod
# 4  ff750bfca4910cfa7f538fbe5463457839021680   6:38 AM   $8.22         NaN
#
#   shirt size   condition
# 0          S        used
# 1          L  never worn
# 2          L        used
# 3         XS         NaN
# 4        2XL        used

# %%
df.tail()
# Out:
#                                         tx id      time auction   color  \
# 995  6fa16b110f53367cf15e6e1dcffdcb4c2653f1ab   9:56 AM   $5.79  Violet
# 996  2b7b6cbc2224502c7137262575e97a450b336fc2  11:31 AM  $14.07  Purple
# 997  7f2a5141de8a7f752f8f98722393ffa3b0fb1e7a   6:25 AM  $17.63  Yellow
# 998  c4549687dee4d3061fd3c82433367bea083d4d05   2:22 AM  $17.00  Yellow
# 999  abf227d09fe37b3e333b419e0854c6c2fd1caa50   7:47 PM  $17.05  Indigo
#
#     shirt size condition
# 995        2XL       NaN
# 996          S      Used
# 997         XS      used
# 998          L      Used
# 999         XL      used

# %%
df.shape
# Out:
# (1000, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tx id       1000 non-null   object
#  1   time        1000 non-null   object
#  2   auction     1000 non-null   object
#  3   color       977 non-null    object
#  4   shirt size  1000 non-null   object
#  5   condition   847 non-null    object
# dtypes: object(6)
# memory usage: 47.0+ KB

# %%
df.isna().sum()
# Out:
# tx id           0
# time            0
# auction         0
# color          23
# shirt size      0
# condition     153
# dtype: int64

# %%
df.columns = df.columns.str.replace(' ', '_').str.lower()

# %%
for col in df.columns[3:]:
  print(col)
  print(df[col].value_counts(dropna=False))
  print()
  print()
# Out:
# color
# Yellow        75
# Maroon        59
# Violet        57
# Khaki         56
# Fuscia        55
# Aquamarine    55
# Turquoise     54
# Green         51
# Blue          51
# Pink          51
# Goldenrod     51
# Crimson       50
# Mauv          50
# Red           49
# Indigo        49
# Orange        49
# Purple        45
# Teal          37
# Puce          33
# NaN           23
# Name: color, dtype: int64
#
#
# shirt_size
# XS     157
# 3XL    152
# S      149
# M      148
# XL     141
# 2XL    129
# L      124
# Name: shirt_size, dtype: int64
#
#
# condition
# used          561
# Never Worn    169
# NaN           153
# Used           64
# never worn     53
# Name: condition, dtype: int64

# %%
df = df.apply(lambda s: s.str.lower().str.replace(' ', '_'))

# %%
df.sample(50)
# Out:
#                                         tx_id      time auction       color  \
# 746  24cd05a7af867ea51149d0218994847ca001bf93  12:36_am  $10.06      maroon
# 909  47cfc3000f4fb479ac8c605d67c76c60245c4570   1:33_am   $8.26      violet
# 104  f5295ef798177b95ee36510b88fa92078124467f   3:20_am  $16.90      yellow
# 55   2742b1da330c4f7f11830d551f0130d74236f1e1   8:24_am  $14.62        mauv
# 421  e9a9aa1896ef145c6cf04b2d502e0dd9284b43bd   3:26_pm  $14.51     crimson
# 558  01d633cd097bead31687596d41f51356c48e852f  12:48_am  $11.08     crimson
# 336  336686259e5b99224266394370e147ddfd824b01   8:47_am  $18.77        puce
# 935  8548c08341474ae3c8673f174a310c8f0bc09fc3   1:33_am  $15.58      orange
# 31   cedebcdd057263f3f0df920828f9621bc8089c6b   6:14_pm  $17.06         NaN
# 841  d1e1265ebf1bf9f263a63e4f39f8e3b3a3ebd0c6   6:59_am  $10.66        mauv
# 648  2183d1a178332a2694bbbcca67b06f3a45adec02   9:01_am   $3.27      orange
# 339  d7d6949c44c00946a247f21c7f32343b4214480e   2:53_pm   $8.14      indigo
# 880  e591333232f04bf091d9f62c2bd33231dec03f68   4:55_pm  $14.22       green
# 110  3be006cd69f9ed68a88352dab26e8edfcb9ebce5  11:56_am  $11.26     crimson
# 447  738e30f26870d1e79443d606bdd004ec313f2d63   8:18_am  $17.61       khaki
# 545  f90a320f8f13bfe3d87f1a77989a546fe299cde3   1:24_am   $7.23      yellow
# 313  45bbe3f0e1fcb2a1c9d0ebd676dda14cfb528951   3:20_am  $15.72       green
#
#     shirt_size   condition
# 746          l         NaN
# 909         xl        used
# 104        3xl        used
# 193          m        used
# 453          m        used
# 62          xs  never_worn
# 890         xl        used
# 520          m  never_worn
# 461         xs         NaN
# 789          m        used
# 813          m        used
# 332         xs         NaN
# 126        2xl  never_worn
# 775          m  never_worn
# 705          s  never_worn
# 43         2xl        used
# 931        3xl  never_worn
# 385         xl        used
# 119          l        used
# 637        2xl        used
# 397          l        used
# 212        2xl  never_worn
# 392          l  never_worn
# 184        3xl  never_worn
# 139        3xl        used
# 149         xs         NaN
# 711         xs        used
# 554          m         NaN
# 536        3xl        used
# 350          s        used
# 411        3xl        used
# 866        3xl        used
# 151        3xl        used
# 160        2xl  never_worn
# 776          l  never_worn
# 856          m        used
# 55           s        used
# 421         xl         NaN
# 558          m        used
# 336        2xl        used
# 935         xs        used
# 31          xs        used
# 841        3xl        used
# 648          s        used
# 339          s         NaN
# 880        2xl  never_worn
# 110        3xl        used
# 447        2xl         NaN
# 545          s        used
# 313        3xl         NaN

# %%
for col in df.columns[3:]:
  print(col)
  print(df[col].value_counts(dropna=False))
  print()
  print()
# Out:
# color
# yellow        75
# maroon        59
# violet        57
# khaki         56
# fuscia        55
# aquamarine    55
# turquoise     54
# green         51
# blue          51
# pink          51
# goldenrod     51
# crimson       50
# mauv          50
# red           49
# indigo        49
# orange        49
# purple        45
# teal          37
# puce          33
# NaN           23
# Name: color, dtype: int64
#
#
# shirt_size
# xs     157
# 3xl    152
# s      149
# m      148
# xl     141
# 2xl    129
# l      124
# Name: shirt_size, dtype: int64
#
#
# condition
# used          625
# never_worn    222
# NaN           153
# Name: condition, dtype: int64
